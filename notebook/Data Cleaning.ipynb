# %% [markdown]
# # Data Cleaning
#
# In this part we conduct data preprocessing

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.mode.chained_assignment = None

# %%
dataset_path = "../dataset/"
data = pd.read_csv(dataset_path + "data_joined.csv")
a = data.dropna()

# %% [markdown]
# ## Currency attribute
#
# **Input**: array of money strings
#
# **Output**: array of normalized money amount

# %%
def parseMoney(beforeParsed):
    afterParsed = []
    for money in beforeParsed:
        #Loại bỏ ký tự '$' và ',' trong xâu rồi chuyển về dạng integer
        afterParsed.append(int(money.strip('$').replace(',',"")))
    return afterParsed

# %% [markdown]
# ## Multivalued attributes
#
# Multivalued attributes is seperated by comma (,)
#
# 1. Input
# - InputArray: Cast, Genre and Studios attributes
# - Money: array of currency processed in the previous step
# - name: attribute name
#
# 2. Output
# Một dataFrame chứa thông tin sau khi được tách ra khỏi các chuỗi, số tiền tương ứng và số lượng của chúng

# %%
def parseWithMoneyAndCount(InputArray, Money, name):
    result = []
    count = []
    gross = []
    i = 0
    for inputarray in InputArray:
    #Chuyển hóa thành str và loại bỏ dấu ',', inputarray lúc này là một mảng chưa các chuỗi sau khi được split ra từ chuỗi ban đầu
        inputarray = str(inputarray).split(',')
        for x in inputarray:
            #Lưu kết quả vào mảng tương ứng
            result.append(x)
            gross.append(Money[i])
            count.append(1)
        i = i+1
    #Tạo dataFrame
    t = pd.DataFrame({name:result, 'Money':gross, 'Count':count})
    #Loại bỏ các giá trị trùng nhau và cộng các hàng tương ứng lại 
    result = t.groupby(name).sum()
    #Sắp xếp lại dataFrame
    sort_by_money = result.sort_values('Money', ascending = False)
    return sort_by_money

# %% [markdown]
# ## Xử lý dữ liệu với cột Cast, Genre, Studios, ListOfCertificate
#
# Tách lấy thông tin cần thiết
#
# Tính tổng số doanh thu của những bộ phim mà họ từng tham gia

# %%
# phần Money trong hàm này cần được chuẩn hóa bằng hàm xử lý tiền tệ trước khi truyền vào
cast = parseWithMoneyAndCount(a['Cast'], parseMoney(a['Gross_worldwide']), 'Cast')
cast
# Out:
#                           Money  Count
# Cast
# Samuel L. Jackson   18097217390     69
# Robert Downey Jr.   15039939731     46
# Scarlett Johansson  14258148970     40
# Zoe Saldana         12144395230     25
# Dwayne Johnson      11942043248     33
# ...                         ...    ...
# Albert Bassermann           623      1
# Joel McCrea                 623      1
# Celia Lovsky                210      1
# Leigh Taylor-Young          210      1
# John Barclay                210      1
#
# [46435 rows x 2 columns]

# %% [markdown]
# Tương tự với cột Genre, Studios và ListOfCertificate

# %%
genre = parseWithMoneyAndCount(a['Genre'], parseMoney(a['Gross_worldwide']), 'Genre')
genre
# Out:
#                     Money  Count
# Genre
# Adventure    271203912453   1161
# Action       257268035537   1535
# Drama        199377563689   2984
# Comedy       191333750413   2168
# Thriller     160628756737   1823
# Sci-Fi       145452690013    740
# Fantasy      138259562425    754
# Family       114324969365    625
# Romance       96987409936   1390
# Crime         78606753606   1205
# Animation     64273357834    215
# Mystery       57614771596    693
# Horror        37419144786    603
# Musical       27052633768    169
# Biography     24516724097    430
# Music         17639492474    255
# War           17530838913    239
# History       16252113465    248
# Sport         13439081193    239
# Western        6974929320    115
# Documentary    1742563943     42
# Film-Noir         4715774      8

# %%
studio = parseWithMoneyAndCount(a['Studios'], parseMoney(a['Gross_worldwide']), 'Studio')
studio
# Out:
#                                           Money  Count
# Studio
# Walt Disney Pictures                66349391865    178
# Warner Bros.                        62019091303    382
# Universal Pictures                  56650572201    401
# Paramount Pictures                  51495436684    348
# Columbia Pictures                   49959064950    355
# ...                                         ...    ...
# Paul Gregory Productions                   2001      1
# Regal Films                                1501      1
# Orion-Nova Productions                      955      1
# Paramount Famous Lasky Corporation          746      1
# Walter Wanger Productions                   623      1
#
# [4214 rows x 2 columns]

# %%
certificate = parseWithMoneyAndCount(a['ListOfCertificate'], parseMoney(a['Gross_worldwide']), 'Certificates')
certificate
# Out:
#                      Money  Count
# Certificates
# PG-13         264982601985   1786
# R             144977990632   2555
# PG            122462092033   1015
# TV-14         102291704291    711
# TV-PG          90327851616    421
# TV-G           37743099587    131
# G              21826637967    148
# TV-MA          20550705456    191
# TV-Y7           3761063398     18
# TV-Y7-FV        1054292942      6
# TV-Y             901965612      8
# NC-17            657982970     16
# 12               493214993      1
# GP               455141855     16
# AO               278780441      1
# M                273160191      7
# X                133718707      4
# M/PG               5561422      2

# %% [markdown]
# ## Xử lý dữ liệu cột Keywords, Languages, Countries
# Dữ liệu dạng này chủ yếu chỉ cần tách và xem xét đến độ phổ biến nên chỉ cần đếm số lượng

# %%
def parseWithCount(InputArray, name):
    result = []
    count = []
    i = 0
    for inputarray in InputArray:
        # Loại bỏ dấu ',' 
        inputarray = str(inputarray).split(',')
        for x in inputarray:
            result.append(x)
            count.append(1)
    result = pd.DataFrame({name:result, 'Count':count})
    #Loại bỏ trùng lặp 
    result = result.groupby(name).sum()
    sort_by_count = result.sort_values('Count', ascending=False)
    return sort_by_count

# %% [markdown]
# ### Cột keywords

# %%
keywords = parseWithCount(a['Keywords'], 'Keywords')
keywords
# Out:
#                       Count
# Keywords
# female nudity           115
# new york city           109
# murder                  105
# female protagonist      101
# sex scene                98
# ...                     ...
# hebrew                    1
# heavyweight champion      1
# heavy water               1
# heavy breathing           1
# zorro character           1
#
# [10180 rows x 1 columns]

# %% [markdown]
# ### Cột Languages

# %%
languages = parseWithCount(a['Languages'], 'Languages')
languages
# Out:
#                          Count
# Languages
# English                   5374
# Spanish                    661
# French                     583
# German                     319
# Italian                    274
# ...                        ...
# Maltese                      1
# Malayalam                    1
# Sinhala                      1
# Brazilian Sign Language      1
# Quechua                      1
#
# [159 rows x 1 columns]

# %% [markdown]
# ### Cột Countries

# %%
countries = parseWithCount(a['Countries'], 'Countries')
countries
# Out:
#                                 Count
# Countries
# United States                    5060
# United Kingdom                    945
# Canada                            497
# France                            428
# Germany                           409
# ...                               ...
# Occupied Palestinian Territory      1
# Jamaica                             1
# Kazakhstan                          1
# Lithuania                           1
# Afghanistan                         1
#
# [92 rows x 1 columns]

# %% [markdown]
# ## Chuẩn hóa lại dữ liệu dạng thời gian
# ### 1. Dữ liệu cột runtime dạng giờ-phút
# Chuyển toàn bộ về phút

# %%
run_time = a['Runtime']
result = []
for time in run_time:
    time = str(time)
    # Loại bỏ khoảng trắng
    time = time.replace(" ", "")
    # nếu trong chuỗi có chứa 'hour' -> có 2 khả năng là chuỗi có chứa 'hours' hoặc 'hour' 
    if "hour" in time:
        hours = 0
        # Nếu chuỗi chứa 'hours', loại bỏ 'hours' và lấy ký tự đầu tiên nhân với 60
        if "hours" in time:
            hours = int(time[0])*60
            after_eliminate_hour = time.replace("hours", "")
        else:
        # Nếu không thì nghĩa là ký tự đầu tiên bằng 1 => 60 phút
            hours = 60
            after_eliminate_hour = time.replace("hour", "")
        minutes = 0
        # Sau đó lấy số phút đó cộng với số phút nếu có đằng sau 
        if "minute" in after_eliminate_hour:
            if "minutes" in after_eliminate_hour:
                minutes = int(after_eliminate_hour.replace("minutes","")[1:])
            else:
                minutes = 1
        result.append(hours+minutes)
    # Nếu chuỗi không chứa 'hour' -> chỉ cần loại bỏ chuỗi 'minutes' rồi chuyển về int là xong
    else:
        result.append(int(time.replace("minutes","")))
        
run_time = pd.DataFrame({'Movie_Title':a['Movie_Title'], 'Time':result})
run_time
# Out:
#                                      Movie_Title  Time
# 0     Star Wars: Episode VII - The Force Awakens   138
# 1                                      Frozen II   103
# 2                          The Dark Knight Rises   164
# 3                           Beauty and the Beast   129
# 4                                   Finding Dory    97
# ...                                          ...   ...
# 9781                           Avengers: Endgame   181
# 9782                                     Titanic   194
# 9783                                      Avatar   162
# 9784                     Lara Croft: Tomb Raider   100
# 9786                          Batman &amp; Robin   125
#
# [5460 rows x 2 columns]

# %% [markdown]
# ### 2. Dữ liệu cột release_date dạng ngày tháng năm
# Tách ngày, tháng, năm của từng bộ phim

# %%
year = []
month = []
date = []
for time in a['Release_Data']:
    year.append(int(str(time)[0:4]))
    month.append(int(str(time)[5:7]))
    date.append(int(str(time)[8:10]))
release_time = pd.DataFrame({'Movie':a['Movie_Title'], 'Date':date, 'Month':month, 'Year':year})
release_time
# Out:
#                                            Movie  Date  Month  Year
# 0     Star Wars: Episode VII - The Force Awakens    18     12  2015
# 1                                      Frozen II    22     11  2019
# 2                          The Dark Knight Rises    27      7  2012
# 3                           Beauty and the Beast    17      3  2017
# 4                                   Finding Dory    17      6  2016
# ...                                          ...   ...    ...   ...
# 9781                           Avengers: Endgame    26      4  2019
# 9782                                     Titanic    18     12  1997
# 9783                                      Avatar    18     12  2009
# 9784                     Lara Croft: Tomb Raider    15      6  2001
# 9786                          Batman &amp; Robin    20      6  1997
#
# [5460 rows x 4 columns]

# %% [markdown]
# ## Xử lý dữ liệu cột Rating và Rating_Count
# - Chuẩn hóa lại dữ liệu cột Rating_Count và chuyển dữ liệu cột Rating về float

# %%
rating_count = a['Rating_Count']
result = []
# Đưa dữ liệu cột rating_count về integer
for rate in rating_count:
    rate = str(rate)
    if 'M' in rate:
        result.append(int(float(rate.replace("M", ""))*1000000))
        continue
    elif 'K' in rate:
        result.append(int(float(rate.replace("K", ""))*1000))
        continue
    else:
        result.append(int(rate))
# Đưa dữ liệu cột rating về dạng float
rating = []
for rate in a['Rating']:
    rating.append(float(rate))
rating = pd.DataFrame({'Movie_Title':a['Movie_Title'], 'Rating':rating, 'Count':result})
rating
# Out:
#                                      Movie_Title  Rating    Count
# 0     Star Wars: Episode VII - The Force Awakens     7.8   893000
# 1                                      Frozen II     6.8   156000
# 2                          The Dark Knight Rises     8.4  1600000
# 3                           Beauty and the Beast     7.1   293000
# 4                                   Finding Dory     7.3   259000
# ...                                          ...     ...      ...
# 9781                           Avengers: Endgame     8.4   977000
# 9782                                     Titanic     7.8  1100000
# 9783                                      Avatar     7.8  1200000
# 9784                     Lara Croft: Tomb Raider     5.8   205000
# 9786                          Batman &amp; Robin     3.8   243000
#
# [5460 rows x 3 columns]

# %%
data
# Out:
#                                      Movie_Title  Movie_ID        Budget  \
# 0     Star Wars: Episode VII - The Force Awakens   2488496  $245,000,000
# 1                                      Frozen II   4520988  $150,000,000
# 2                          The Dark Knight Rises   1345836  $250,000,000
# 3                           Beauty and the Beast   2771200  $160,000,000
# 4                                   Finding Dory   2277860  $200,000,000
# ...                                          ...       ...           ...
# 9782                                     Titanic    120338  $200,000,000
# 9783                                      Avatar    499549  $237,000,000
# 9784                     Lara Croft: Tomb Raider    146316  $115,000,000
# 9785                          The Long Walk Home    100046           NaN
# 9786                          Batman &amp; Robin    118688  $125,000,000
#
#                                                    Cast  \
# 0     Daisy Ridley,John Boyega,Oscar Isaac,Domhnall ...
# 1     Kristen Bell,Idina Menzel,Josh Gad,Jonathan Gr...
# 2     Christian Bale,Tom Hardy,Anne Hathaway,Gary Ol...
# 3     Emma Watson,Dan Stevens,Luke Evans,Josh Gad,Ke...
# 4     Ellen DeGeneres,Albert Brooks,Ed O'Neill,Kaitl...
# ...                                                 ...
# 9782  Leonardo DiCaprio,Kate Winslet,Billy Zane,Kath...
# 9783  Sam Worthington,Zoe Saldana,Sigourney Weaver,M...
# 9784  Angelina Jolie,Jon Voight,Iain Glen,Noah Taylo...
# 9785  Sissy Spacek,Whoopi Goldberg,Dwight Schultz,Vi...
# 9786  Arnold Schwarzenegger,George Clooney,Chris O'D...
#
#                                                    Crew  \
# 0             Lawrence Kasdan,Michael Arndt,J.J. Abrams
# 1       Jennifer Lee,Hans Christian Andersen,Chris Buck
# 2       Jonathan Nolan,Christopher Nolan,David S. Goyer
# 3     Evan Spiliotopoulos,Bill Condon,Stephen Chbosk...
# 4         Angus MacLane,Victoria Strouse,Andrew Stanton
# ...                                                 ...
# 9782                                      James Cameron
# 9783                                      James Cameron
# 9784  Mike Werb,Sara B. Cooper,Simon West,Michael Co...
# 9785                           John Cork,Richard Pearce
# 9786            Akiva Goldsman,Joel Schumacher,Bob Kane
#
#                                                 Studios  \
# 0             Lucasfilm,Bad Robot,Truenorth Productions
# 1     Walt Disney Animation Studios,Walt Disney Pict...
# 2     Warner Bros.,Legendary Entertainment,DC Entert...
# 3                 Mandeville Films,Walt Disney Pictures
# 4          Pixar Animation Studios,Walt Disney Pictures
# ...                                                 ...
# 9782  Twentieth Century Fox,Paramount Pictures,Light...
# 9783  Twentieth Century Fox,Dune Entertainment,Light...
# 9784   Paramount Pictures,Mutual Film Company,BBC Films
# 9785          Dave Bell Associates,New Visions Pictures
# 9786         Warner Bros.,PolyGram Filmed Entertainment
#
#                                                   Genre  \
# 0                               Action,Adventure,Sci-Fi
# 1     Animation,Adventure,Comedy,Family,Fantasy,Musical
# 2                                    Action,Crime,Drama
# 3              Adventure,Family,Fantasy,Musical,Romance
# 4                     Animation,Adventure,Comedy,Family
# ...                                                 ...
# 9782                                      Drama,Romance
# 9783                    Action,Adventure,Fantasy,Sci-Fi
# 9784                  Action,Adventure,Fantasy,Thriller
# 9785                                      Drama,History
# 9786                                      Action,Sci-Fi
#
#                                                Keywords  \
# 0     reboot,sanitation employee,remake,crash landin...
# 1     autumn,anthropomorphic snowman,princess,disney...
# 2     dc comics,batman character,bruce wayne charact...
# 3     beast,fairy tale,heroine,beast's heart,remake ...
# 4     fish,ocean,whale,octopus driving a truck,talki...
# ...                                                 ...
# 9782  iceberg,sailor's death,love affair,sunken ship...
# 9783  spiritualism,paraplegic,marine,future,forest p...
# 9784  female nudity,handheld weapon,strong female le...
# 9785  scene during opening credits,alabama,montgomer...
# 9786         bat nipples,heavy breathing,pun,ice,freeze
#
#                                   Languages  \
# 0                                   English
# 1                                   English
# 2                            English,Arabic
# 3                                   English
# 4                        English,Indonesian
# ...                                     ...
# 9782         English,Swedish,Italian,French
# 9783                        English,Spanish
# 9784  English,Central Khmer,Russian,Italian
# 9785                                English
# 9786                                English
#
#                                        Countries  \
# 0                                  United States
# 1                                  United States
# 2                   United Kingdom,United States
# 3                                  United States
# 4                                  United States
# ...                                          ...
# 9782              United States,Mexico,Australia
# 9783                               United States
# 9784  United States,United Kingdom,Japan,Germany
# 9785                               United States
# 9786                United States,United Kingdom
#
#                                        Filming_Location Release_Data  \
# 0                Skellig Michael, County Kerry, Ireland   2015-12-18
# 1                                         Norway, Norge   2019-11-22
# 2            Mehrangarh Fort, Jodhpur, Rajasthan, India   2012-07-27
# 3     Shepperton Studios, Studios Road, Shepperton, ...   2017-03-17
# 4     Pixar Animation Studios - 1200 Park Avenue, Em...   2016-06-17
# ...                                                 ...          ...
# 9782  Titanic wreck, Titanic Canyon, North Atlantic,...   1997-12-18
# 9783                         Hamakua Coast, Hawaii, USA   2009-12-18
# 9784                    Angkor Wat, Siem Reap, Cambodia   2001-06-15
# 9785                           Montgomery, Alabama, USA   1991-04-12
# 9786                           Montréal, Québec, Canada   1997-06-20
#
#                  Runtime Gross_worldwide  Rating Rating_Count  \
# 0     2 hours 18 minutes  $2,069,521,700     7.8         893K
# 1      1 hour 43 minutes  $1,450,026,933     6.8         156K
# 2     2 hours 44 minutes  $1,081,142,612     8.4         1.6M
# 3      2 hours 9 minutes  $1,273,576,220     7.1         293K
# 4      1 hour 37 minutes  $1,028,570,942     7.3         259K
# ...                  ...             ...     ...          ...
# 9782  3 hours 14 minutes  $2,201,647,264     7.8         1.1M
# 9783  2 hours 42 minutes  $2,847,246,203     7.8         1.2M
# 9784   1 hour 40 minutes    $274,703,340     5.8         205K
# 9785   1 hour 37 minutes      $4,873,620     7.3         3.8K
# 9786   2 hours 5 minutes    $238,235,719     3.8         243K
#
#       ListOfCertificate
# 0                 PG-13
# 1                    PG
# 2           PG-13,TV-14
# 3              PG,TV-PG
# 4               TV-G,PG
# ...                 ...
# 9782  PG-13,TV-PG,TV-14
# 9783        PG-13,TV-14
# 9784              PG-13
# 9785                 PG
# 9786        PG-13,TV-PG
#
# [9787 rows x 17 columns]

# %% [markdown]
# ## Xuất ra file CSV

# %%
cast.to_csv(dataset_path + "Cast.csv", index = False)
genre.to_csv(dataset_path + "Genre.csv", index = False)
studio.to_csv(dataset_path + "Studio.csv", index = False)
keywords.to_csv(dataset_path + "Keywords.csv", index = False)
languages.to_csv(dataset_path + "Languages.csv", index = False)
countries.to_csv(dataset_path + "Countries.csv", index = False)
run_time.to_csv(dataset_path + "Run_time.csv", index = False)
release_time.to_csv(dataset_path + "Release_time.csv", index = False)
rating.to_csv(dataset_path + "Rating.csv", index = False)

# %%
relationship = a["Budget"]
test = {
    'Title': a['Movie_Title'],
    'Budget':parseMoney(a['Budget']),
    'Worldwide Box Office': parseMoney(a['Worldwide Box Office'])
}
test = pd.DataFrame(test)
test.plot(kind="scatter", x = "Budget", y = "Worldwide Box Office")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9160/232560986.py in <module>
#       2 test = {
#       3     'Title': a['Movie_Title'],
# ----> 4     'Budget':parseMoney(a['Budget']),
#       5     'Worldwide Box Office': parseMoney(a['Worldwide Box Office'])
#       6 }
#
# ~\AppData\Local\Temp/ipykernel_9160/3200694968.py in parseMoney(beforeParsed)
#       3     for money in beforeParsed:
#       4         #Loại bỏ ký tự '$' và ',' trong xâu rồi chuyển về dạng integer
# ----> 5         afterParsed.append(int(money.strip('$').replace(',',"")))
#       6     return afterParsed
#
# ValueError: invalid literal for int() with base 10: '€17000000'
